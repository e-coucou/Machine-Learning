# %%
import sys, os
sys.path.insert(0, '..')

import numpy  as np
import tensorflow as tf
import math

from model.exp import Exp, load

import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

from tqdm import tqdm

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# WARNING:tensorflow:From c:\Users\eplaidy\AppData\Local\anaconda3\envs\EP\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from pickle import dump
# with open('./scaler/scaler.sav', 'wb') as file:
#     dump(myExpFct.dataFct.scalerData, file)

with open('./settings/settings.sav', 'wb') as file:
    dump(settings, file)

# %%
exp = Exp(settings)
settings = exp.load()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 settings = {}
# ----> 2 exp = Exp(settings)
#       3 settings = exp.load()
#
# File c:\Users\eplaidy\OneDrive - ADISSEO\Documents\GitHub\Machine-Learning\1-Projet\Achats\ep\Gas - Fixing\informer\test-gas\..\model\exp.py:19, in Exp.__init__(self, settings, **kwargs)
#      17 super(Exp, self).__init__(**kwargs)
#      18 self.settings=settings
# ---> 19 self.global_size = settings["global_size"]
#      20 self.batch_size = settings["batch_size"]
#      21 self.seq_len = settings["seq_len"]
#
# KeyError: 'global_size'
