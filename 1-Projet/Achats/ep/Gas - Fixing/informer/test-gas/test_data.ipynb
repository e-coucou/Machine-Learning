# %%
import sys, os
sys.path.insert(0, '..')
from model.data import getGasData

my = getGasData(seq_len=96, batch_len=32,global_size=1000)
data = my.get()
print(my.df_Data.info())
print('------- les vecteurs & la Base --')
for vecteur in list(data):
    print(vecteur.shape)
my.display()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3126 entries, 2012-01-16 to 2024-04-26
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Day-ahead     3126 non-null   float64
#  1   Month-ahead   3126 non-null   float64
#  2   Year-Ahead    3126 non-null   float64
#  3   2 Year-Ahead  3126 non-null   float64
#  4   mois          3126 non-null   int64
#  5   jour          3126 non-null   int64
#  6   sJour         3126 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 195.4 KB
# None
# ------- les vecteurs & la Base --
# (1000, 96, 4)
# (1000, 96, 3)
# (1000, 4)
# (1000, 3)
# (1000, 7)
# 2024-09-14 18:43:51.757286: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-09-14 18:43:51.757306: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-09-14 18:43:51.757316: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# ...

# %%
my.displayNorm()
