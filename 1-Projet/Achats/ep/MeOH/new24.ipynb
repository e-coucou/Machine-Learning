# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def map_(v,x1,x2,y1,y2):
    ret = (v-x1)/(x2-x1) * (y2-y1) + y1
    return ret

# %%
spot_mini = 150
spot_maxi = 400
eqcp_mini = 225
eqcp_maxi = 550
inc=5
risque=15
eqcp_nb= (eqcp_maxi-eqcp_mini)/inc
spot_nb = (spot_maxi-spot_mini)/inc
print(spot_nb,eqcp_nb)
# map()
# Out:
# 50.0 65.0

# %%
eqcp_list = np.array([i for i in range(eqcp_mini,eqcp_maxi,inc)])
spot_list = np.array([i for i in range(spot_mini,spot_maxi,inc)])

# %%
def get_price(eqcp,spot):
    new_rebate = ( 0.335 if eqcp>=475 else 0.325 if eqcp>=400 else 0.315)
    var_spot2 = 0.40 if (((1-new_rebate)*eqcp+risque)>(spot)) else 0.
    new_price = eqcp * (1-new_rebate) * (1-var_spot2) + var_spot2*spot
    old_rebate = ( 0.28 if eqcp>=400 else 0.26 if eqcp >300 else 0.24)
    var_spot = 0.20 if (((1-old_rebate)*eqcp+risque)>(spot)) else 0.
    old_price = eqcp * (1-old_rebate) * (1-var_spot) + var_spot*spot
    return new_price,old_price,new_rebate, old_rebate,var_spot,var_spot2

# %%
risque = -10
eqcp = 475
spot = 325
n,o,nR,oR,vs,vs2 = get_price(eqcp=eqcp, spot=spot)
print(n,o,n-o,nR,oR,vs*100,vs2*100,'risque',risque)
# Out:
# 315.875 338.6 -22.725000000000023 0.335 0.28 20.0 0.0 risque -10

# %%
df = pd.DataFrame(columns=eqcp_list)
for e in eqcp_list:
    pdS = pd.Series()
    for s in spot_list:
        n,o,_,_ = get_price(eqcp=e,spot=s)
        pdS[s] = int(o-n)
    df[e] = pdS
#df

# %%
y_ = pd.Series()
for x_ in eqcp_list:
    vx= map_(x_*0.65,eqcp_mini,eqcp_maxi,0,eqcp_nb-1)
    vy = map_(vx,spot_nb-1, 0,spot_mini,spot_maxi)
    y_[vx] = vy
print(y_)
# Out:
# -15.507692    479.120879
# -14.867692    475.855573
# -14.227692    472.590267
# -13.587692    469.324961
# -12.947692    466.059655
#                  ...
#  22.892308    283.202512
#  23.532308    279.937206
#  24.172308    276.671900
#  24.812308    273.406593
#  25.452308    270.141287
# Length: 65, dtype: float64

# %%
risque = -10
fig,ax = plt.subplots(figsize=(28,15))
# sns.set_palette("Paired")
plt.tick_params(bottom='on')
g = sns.heatmap(df.values,annot=True,xticklabels=eqcp_list, yticklabels=spot_list, linewidth=.5 ,cmap='PiYG', vmin=0, vmax=40,cbar=False);
# im = ax.imshow(df ,cmap='PiYG', vmin=-15, vmax=15, aspect='auto');
g.set_xlabel('EQCP');
g.set_ylabel('Spot');
# ax2 = plt.twinx()
# x_ = (eqcp_list-eqcp_mini)/5
# y_ = (x_.max()-x_)*0.7
# sns.lineplot(x=x_, y=y_, linewidth=5, ax=ax2);
# ax.plot(eqcp_list*0.7, linewidth=50);
# ax2.axis('tight')

# %%
545*0.65
# Out:
# 354.25

# %%
geyser = sns.load_dataset("geyser")
geyser
# Out:
#      duration  waiting   kind
# 0       3.600       79   long
# 1       1.800       54  short
# 2       3.333       74   long
# 3       2.283       62  short
# 4       4.533       85   long
# ..        ...      ...    ...
# 267     4.117       81   long
# 268     2.150       46  short
# 269     4.417       90   long
# 270     1.817       46  short
# 271     4.467       74   long
#
# [272 rows x 3 columns]

# %%
fig = plt.figure(figsize=(28,15))
sns.set_palette("Paired")
graphe2 = sns.displot(data=df, x=df[200], y=df[350], kind='kde');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\eplaidy\AppData\Local\anaconda3\envs\EP\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:4484, in pandas._libs.hashtable.Int32HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:4508, in pandas._libs.hashtable.Int32HashTable.get_item()
#
# KeyError: 200
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 fig = plt.figure(figsize=(28,15))
#       2 sns.set_palette("Paired")
# ----> 3 graphe2 = sns.displot(data=df, x=df[200], y=df[350], kind='kde');
#
# File c:\Users\eplaidy\AppData\Local\anaconda3\envs\EP\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\eplaidy\AppData\Local\anaconda3\envs\EP\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 200
