# %%
from keras import Sequential, Model
import numpy as np
from keras import Input
from keras import layers

# %%
# le model Keras
input_data = Input(shape=(64,))
x = layers.Dense(32, activation='relu')(input_data)
x = layers.Dense(32, activation='relu')(x)
output_data = layers.Dense(10, activation='softmax')(x)
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-05-26 16:36:03.473245: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-26 16:36:03.473499: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = Model(input_data,output_data)
model.compile(optimizer='rmsprop',loss='categorical_crossentropy')
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64)]              0
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 3,466
# Trainable params: 3,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train = np.random.random((1000,64))
y_train = np.random.random((1000,10))
model.fit(X_train,y_train,batch_size=128,epochs=10)
# Out:
# 2022-05-26 16:40:10.209525: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-26 16:40:10.382692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 1/10
# 8/8 [==============================] - 1s 25ms/step - loss: 11.8251
# Epoch 2/10
# 8/8 [==============================] - 0s 7ms/step - loss: 12.0094
# Epoch 3/10
# 8/8 [==============================] - 0s 7ms/step - loss: 12.5421
# Epoch 4/10
# 8/8 [==============================] - 0s 7ms/step - loss: 13.5829
# Epoch 5/10
# 8/8 [==============================] - 0s 7ms/step - loss: 15.3215
# Epoch 6/10
# 8/8 [==============================] - 0s 7ms/step - loss: 17.5322
# Epoch 7/10
# 8/8 [==============================] - 0s 7ms/step - loss: 20.1032
# Epoch 8/10
# 8/8 [==============================] - 0s 7ms/step - loss: 22.9050
# Epoch 9/10
# 8/8 [==============================] - 0s 7ms/step - loss: 26.1468
# Epoch 10/10
# 8/8 [==============================] - 0s 7ms/step - loss: 29.8957

# %%
score = model.evaluate(X_train,y_train)
# Out:
# 32/32 [==============================] - 0s 6ms/step - loss: 32.0251

# %%
import matplotlib.pyplot as plt
plt.plot(y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x169971580>,
#  <matplotlib.lines.Line2D at 0x1699715e0>,
#  <matplotlib.lines.Line2D at 0x169971700>,
#  <matplotlib.lines.Line2D at 0x169971820>,
#  <matplotlib.lines.Line2D at 0x169971940>,
#  <matplotlib.lines.Line2D at 0x169971a60>,
#  <matplotlib.lines.Line2D at 0x169971b80>,
#  <matplotlib.lines.Line2D at 0x169971ca0>,
#  <matplotlib.lines.Line2D at 0x169971dc0>,
#  <matplotlib.lines.Line2D at 0x169971ee0>]
